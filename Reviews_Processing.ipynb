# %% [markdown]
# ## <center> Reviews Data Enrichment & Processing <center>

# %% [markdown]
# > To perform our impact analysis and more specifically the sentiment analysis, we needed more data telling us more about the movies perception of viewers. We tought of enriching our dataset with reviews as they provide many information on the emotions feeled by viewers towards the film and thus the event the movie might deal with.
# >
# > We found a [dataset](https://www.kaggle.com/datasets/ebiswas/imdb-review-dataset) containing 5.5 million movies reviews from IMDB and merged it to our already box-office and inflation index enriched dataset. However, the file `reviews.csv` being 922.2 MB big, we could not download it directly on GitHub to process it like our other additional datasets. Thus, we decided to proceed to its processing and to the dataset enrichment in a different notebook used locally on our computers where we could download the `reviews.csv` file and directly use it.
# >
# > To run this notebook properly, it should be placed in the same directory as the file `reviews.csv` the file `helpers.py` and the file `movies_with_events.csv` resulting from the first enrichment of our dataset in our main project notebook.

# %%
# Useful Python packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


# Additional functions

from helpers import*

# %%
# Defining paths to the .csv files

REVIEWS_PATH = "reviews.csv"
MOVIES_EVENTS_PATH = "movies_with_events.csv"


# Loading of the .csv files in DataFrames

reviews_df = pd.read_csv(REVIEWS_PATH)
movies_with_events_df = pd.read_csv(MOVIES_EVENTS_PATH)


# Getting an idea of the reviews dataset

reviews_df.head()
# Out:
#    review_id             reviewer                     movie  rating  \
# 0  rw1133942  OriginalMovieBuff21  Kill Bill: Vol. 2 (2004)     8.0
# 1  rw1133959        lost-in-limbo         Feardotcom (2002)     3.0
# 2  rw1133985             NateManD            Persona (1966)    10.0
# 3  rw1133999            CAMACHO-4  War of the Worlds (2005)     3.0
# 4  rw1134010            CAMACHO-4   Mr. & Mrs. Smith (2005)     6.0
#
#                                       review_summary   review_date  \
# 0      Good follow up that answers all the questions  24 July 2005
# 1  "I couldn't make much sense of it myself". Too...  24 July 2005
# 2  Persona gives me all the reasons to love art-h...  24 July 2005
# 3  A disappointing film from the team that you Mi...  24 July 2005
# 4            A fun action movie with great chemistry  24 July 2005
#
#    spoiler_tag                                      review_detail      helpful
# 0            0  After seeing Tarantino's Kill Bill Vol: 1, I g...   ['0', '1']
# 1            0  There's a Website called FearDotCom and anyone...   ['1', '4']
# 2            0  Long before "Muholland Drive" there was anothe...  ['9', '23']
# 3            0  Spielberg said this film is based on the H.G. ...  ['9', '14']
# 4            0  Director Doug Liman, who's gotten famous for m...   ['1', '3']

# %%
# Renaming the column to further perform a merge

movies_with_events_df.rename(columns = {'name': 'movie'}, inplace = True)


# Getting an idea of our enriched dataset

movies_with_events_df.head()
# Out:
#    Unnamed: 0  id_wiki id_freebase                  movie    date  \
# 0           0      330   /m/0ktn59                Actrius  1996.0
# 1           1     3217    /m/014hr       Army of Darkness  1992.0
# 2           2     3333    /m/0151l  The Birth of a Nation  1915.0
# 3           3     3746    /m/017n9           Blade Runner  1982.0
# 4           4     3837    /m/018f8        Blazing Saddles  1974.0
#
#     box_office  runtime                                               lang  \
# 0          NaN     90.0           ['Catalan language', 'Spanish Language']
# 1   21502796.0     81.0                                   English Language
# 2   50000000.0    190.0                ['Silent film', 'English Language']
# 3   33139618.0    116.0  ['Japanese Language', 'Cantonese', 'English La...
# 4  119500000.0     93.0           ['Yiddish Language', 'English Language']
#
#                                      country  \
# 0                                      Spain
# 1                   United States of America
# 2                   United States of America
# 3  ['United States of America', 'Hong Kong']
# 4                   United States of America
#
#                                                genre  ...  Vietnam War  \
# 0                          ['Drama', 'Comedy-drama']  ...        False
# 1  ['Cult', 'Horror', 'Stop motion', 'Costume dra...  ...        False
# 2  ['Silent film', 'Indie', 'Costume drama', 'Epi...  ...        False
# 3  ['Thriller', 'Cyberpunk', 'Science Fiction', '...  ...        False
# 4                    ['Western', 'Satire', 'Comedy']  ...        False
#
#   Black History  Digital Revolution   STDs  Drug Abuse Atomic Bomb  \
# 0         False               False  False       False       False
# 1         False               False  False       False       False
# 2         False               False  False       False       False
# 3         False               False  False       False       False
# 4         False               False  False       False       False
#
#    Genetic Engineering  LGBTQ  Terrorism        events_belongs_to
# 0                False  False      False                       []
# 1                 True  False      False  ['Genetic Engineering']
# 2                False  False      False                       []
# 3                 True  False      False  ['Genetic Engineering']
# 4                False  False      False                       []
#
# [5 rows x 31 columns]

# %%
# The regular expression r'\(\d+\)' matches any substring that starts with '(' followed by one or more digits and ends with ')'
# It is replaced with an empty string, effectively removing it

# Processing the reviews dataset

reviews_df['movie'] = reviews_df['movie'].str.replace(r' \(\d+\)','', regex = True)

# %%
# Merging both datasets

movies_with_events_and_reviews_df = movies_with_events_df.merge(reviews_df, how = 'left', on = ['movie'])

# %%
movies_events_reviews_unique_df = movies_with_events_and_reviews_df.copy()


# Renaming the column 'movie' as in our original dataset

movies_events_reviews_unique_df.rename(columns = {'movie': 'name'}, inplace = True)


# Dropping duplicates

movies_events_reviews_unique_df = movies_events_reviews_unique_df.drop_duplicates(subset = ['Unnamed: 0'], keep = 'first')


# Resetting the index to a default one

index_list = list(movies_events_reviews_unique_df['Unnamed: 0'])
movies_events_reviews_unique_df = movies_events_reviews_unique_df.set_index('Unnamed: 0').reindex(index_list)
movies_events_reviews_unique_df.reset_index(inplace = True)


# Cleaning the columns of our dataset

movies_events_reviews_unique_df = movies_events_reviews_unique_df.drop(['Unnamed: 0'], axis = 1)


# Getting an idea of our final dataset

movies_events_reviews_unique_df.head()
# Out:
#    id_wiki id_freebase                   name    date   box_office  runtime  \
# 0      330   /m/0ktn59                Actrius  1996.0          NaN     90.0
# 1     3217    /m/014hr       Army of Darkness  1992.0   21502796.0     81.0
# 2     3333    /m/0151l  The Birth of a Nation  1915.0   50000000.0    190.0
# 3     3746    /m/017n9           Blade Runner  1982.0   33139618.0    116.0
# 4     3837    /m/018f8        Blazing Saddles  1974.0  119500000.0     93.0
#
#                                                 lang  \
# 0           ['Catalan language', 'Spanish Language']
# 1                                   English Language
# 2                ['Silent film', 'English Language']
# 3  ['Japanese Language', 'Cantonese', 'English La...
# 4           ['Yiddish Language', 'English Language']
#
#                                      country  \
# 0                                      Spain
# 1                   United States of America
# 2                   United States of America
# 3  ['United States of America', 'Hong Kong']
# 4                   United States of America
#
#                                                genre  id_wiki_movie  ...  \
# 0                          ['Drama', 'Comedy-drama']            330  ...
# 1  ['Cult', 'Horror', 'Stop motion', 'Costume dra...           3217  ...
# 2  ['Silent film', 'Indie', 'Costume drama', 'Epi...           3333  ...
# 3  ['Thriller', 'Cyberpunk', 'Science Fiction', '...           3746  ...
# 4                    ['Western', 'Satire', 'Comedy']           3837  ...
#
#   Terrorism        events_belongs_to  review_id       reviewer rating  \
# 0     False                       []        NaN            NaN    NaN
# 1     False  ['Genetic Engineering']  rw1132243       Coventry    7.0
# 2     False                       []  rw1139003    Cineanalyst   10.0
# 3     False  ['Genetic Engineering']  rw1144451       whpratt1   10.0
# 4     False                       []  rw1159971  standardmetal    9.0
#
#                                       review_summary     review_date  \
# 0                                                NaN             NaN
# 1  Bruce Campbell kicks medieval butt in the last...    22 July 2005
# 2                                The Birth of an Art    31 July 2005
# 3                       Looking Forward to Year 2019   7 August 2005
# 4  Blazing Saddles-the DVD (30th Anniversary Spec...  28 August 2005
#
#    spoiler_tag                                      review_detail  \
# 0          NaN                                                NaN
# 1          0.0  Well, one thing you can't possibly say about S...
# 2          1.0  Before "The Birth of a Nation," motion picture...
# 3          0.0  Being a big fan of Harrison Ford, I just can't...
# 4          0.0  Blazing Saddles is such a network favorite on ...
#
#           helpful
# 0             NaN
# 1      ['1', '7']
# 2  ['171', '241']
# 3      ['0', '1']
# 4      ['1', '2']
#
# [5 rows x 38 columns]

# %%
# Checking the NaN percentage in each column of our final enriched dataset

compute_nan_count_and_percentage(movies_events_reviews_unique_df)
# Out:
# id_wiki: 0 NaN values, which represents 0.00 % of the column.
#
# id_freebase: 0 NaN values, which represents 0.00 % of the column.
#
# name: 0 NaN values, which represents 0.00 % of the column.
#
# date: 2619 NaN values, which represents 6.21 % of the column.
#
# box_office: 21004 NaN values, which represents 49.77 % of the column.
#
# runtime: 6624 NaN values, which represents 15.70 % of the column.
#
# lang: 5264 NaN values, which represents 12.47 % of the column.
#
# country: 3312 NaN values, which represents 7.85 % of the column.
#
# genre: 411 NaN values, which represents 0.97 % of the column.
#
# id_wiki_movie: 0 NaN values, which represents 0.00 % of the column.
#
# summary: 0 NaN values, which represents 0.00 % of the column.
#
# popularity: 21604 NaN values, which represents 51.19 % of the column.
#
# vote_average: 21604 NaN values, which represents 51.19 % of the column.
#
# vote_count: 21604 NaN values, which represents 51.19 % of the column.
#
# inflation_index: 0 NaN values, which represents 0.00 % of the column.
#
# inflation_adjusted_box_office: 21004 NaN values, which represents 49.77 % of the column.
#
# new_genre: 1680 NaN values, which represents 3.98 % of the column.
#
# WW1: 0 NaN values, which represents 0.00 % of the column.
#
# WW2: 0 NaN values, which represents 0.00 % of the column.
#
# Space Exploration: 0 NaN values, which represents 0.00 % of the column.
#
# Vietnam War: 0 NaN values, which represents 0.00 % of the column.
#
# Black History: 0 NaN values, which represents 0.00 % of the column.
#
# Digital Revolution: 0 NaN values, which represents 0.00 % of the column.
#
# STDs: 0 NaN values, which represents 0.00 % of the column.
#
# Drug Abuse: 0 NaN values, which represents 0.00 % of the column.
#
# Atomic Bomb: 0 NaN values, which represents 0.00 % of the column.
#
# Genetic Engineering: 0 NaN values, which represents 0.00 % of the column.
#
# LGBTQ: 0 NaN values, which represents 0.00 % of the column.
#
# Terrorism: 0 NaN values, which represents 0.00 % of the column.
#
# events_belongs_to: 0 NaN values, which represents 0.00 % of the column.
#
# review_id: 38344 NaN values, which represents 90.85 % of the column.
#
# reviewer: 38344 NaN values, which represents 90.85 % of the column.
#
# rating: 38641 NaN values, which represents 91.56 % of the column.
#
# review_summary: 38344 NaN values, which represents 90.85 % of the column.
#
# review_date: 38344 NaN values, which represents 90.85 % of the column.
#
# spoiler_tag: 38344 NaN values, which represents 90.85 % of the column.
#
# review_detail: 38344 NaN values, which represents 90.85 % of the column.
#
# helpful: 38344 NaN values, which represents 90.85 % of the column.

# %% [markdown]
# > There is a lot of NaN values in the reviews columns, but it still gives us around 5'000 films that we can consider for our sentiment analysis.

# %%
# Saving our final dataset in a .csv file

movies_events_reviews_unique_df.to_csv('data/AdditionalDatasets/movies_events_reviews.csv')

# %% [markdown]
# > We can now use the enriched dataset with reviews to perform a sentiment analysis.
